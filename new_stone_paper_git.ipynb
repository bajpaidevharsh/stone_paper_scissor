# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# **in the process first we have to make our own data set with the help of our camera and roboflow**

# %%
training=cv2.imread('/content/train_batch0.jpg')
cv2_imshow(training)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1920>

# %% [markdown]
# **then downloading the data set in the yolov8 format**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="#your key")
project = rf.workspace("dev-6o7d0").project("stone_paper_scissor-hrfbb")
version = project.version(2)
dataset = version.download("yolov8")

# %% [markdown]
# **training the model**

# %%
# !pip install ultralytics

# %%
# !yolo task=detect mode=train model=yolov8x.pt data='#path of yaml file' epochs=50

# %% [markdown]
# **check the results**

# %%
results=cv2.imread('/content/confusion_matrix.png')
cv2_imshow(results)
# Out:
# <PIL.Image.Image image mode=RGB size=3000x2250>

# %% [markdown]
# **pick the best weights**

# %% [markdown]
# **after making the game**

# %%
interface=cv2.imread('/content/interface.png')
cv2_imshow(interface)
# Out:
# <PIL.Image.Image image mode=RGB size=796x642>

# %%
game1=cv2.imread('/content/gameplay.png')
cv2_imshow(game1)
# Out:
# <PIL.Image.Image image mode=RGB size=803x636>

# %%
game2=cv2.imread('/content/gameplay_2.png')
cv2_imshow(game2)
# Out:
# <PIL.Image.Image image mode=RGB size=800x642>
